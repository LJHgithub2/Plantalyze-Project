# %% [markdown]
# # 전이 학습(Transfer Learning)
# - 전이 학습은 기존에 학습된 모델 또는 특징 추출기를 사용하여 새로운 작업에 대한 모델을 초기화하거나 초기화한 모델을 추가로 학습시키는 학습 방법
#   - 특징 추출(Feature Extraction)
#     - 기존의 학습된 conv층은 유지하여 일반적인 특징을 캡처. 따라서 새로운 데이터셋에 맞게 분류기만 학습
#   - 미세 조정(Fine-tuning)
#     - 사전 학습된 모델의 일부 또는 전체 레이어를 새로운 작업에 맞게 추가 학습
#     - 모델의 상위 레이어는 새로운 작업에 더 적응되도록 새로운 데이터셋으로 학습.
#     - 일반적으로 학습률(learning rate)을 낮추고, 이전에 학습된 가중치에 더 큰 패널티를 부여하여 오버피팅을 방지.

# %%
# 환경 변수
cfg = {
    'train_size': (512, 512),  # 이미지 크기
    'dict_label': {
        '02': {'00': 0, '03': 1, '04': 2},  # 고추마일드, 고추점무늬
        '05': {'00': 3, '09': 4, '10': 5},  # 상추균핵병, 상추노균병
        '11': {'00': 6, '18': 7, '19': 8},  # 토마토황화잎, 토마토잎곰팡이
    }
}
num_classes = 3 + 3 + 3  # 고추마일드, 고추점무늬, 상추균핵병, 상추노균병, 토마토황화잎, 토마토잎곰팡이

# %% [markdown]
# ### 미세 조정(Fine-tuning)

# %%
import cv2
import numpy as np
import zipfile
from google.colab.patches import cv2_imshow
import tensorflow as tf
import seaborn as sns # 데이터 시각화
# 서로 다른 2개의 모델을 합치기 때문에 순차적은 아니다.
from tensorflow.keras.models import Model
# 전이 학습을 위해 모델 합치기위한 객체
from tensorflow.keras.layers import Dense, Input,GlobalAveragePooling2D, Dropout
# 이미지 전처리를 도와주는 객체( 테스트 데이터, 검증 데이터 분할, 이미지 늘리기 등 )

tf.__version__

# %% [markdown]
# #### Pre-trained Network(사전 학습 모델) Loading
# - ResNet50과 imagenet을 사용한다.
# - Network
#   - ResNet : https://arxiv.org/pdf/1512.03385.pdf
#   - keras에서 제공하는 사전학습 가능한 모델들
#     - documentation : https://keras.io/api/applications/
# - weights
#   - imagenet : https://www.image-net.org/
#   - coco : https://cocodataset.org/#home

# %%
# 사전 학습된 ResNet50 모델을 가져온다. (이미지넷 데이터셋으로 사전 학습된 가중치를 사용한다.)
# include_top = False는 밀집층을 포함하지 않고 모델의 최상위 레이어를 가져온다.
# 이는 사용자가 새로운 작업에 맞게 자신만의 분류기를 추가할 수 있게 한다.
# 각 사전 학습된 모델은 다양한 입력 크기를 지원한다. 사용자는 자신의 데이터셋에 맞는 입력 크기를 선택할 수 있다.

base_model = tf.keras.applications.ResNet50(
    weights='imagenet',  # ImageNet 데이터셋으로 사전 학습된 가중치를 사용.
    include_top=False,   # 최상위 밀집층을 포함하지 않습니다.
    input_tensor=Input(shape=(512, 512, 3))  # 네트워크의 입력 크기를 지정.
)

# %%
base_model.summary()

# %%
len(base_model.layers)

# %%
base_model.trainable = True

# %% [markdown]
# * ResNet50 모델의 각 층은 입력에 대해 다른 수준의 추상화를 학습한다.
#   - 일반적으로 모델의 하위 층은 저수준의 기능(예: 선, 모서리)을 학습하고 상위 층은 더 추상적이고 고수준의 기능(예: 개, 자동차)을 학습한다.
#
#   - 따라서 전체 네트워크를 재학습하는 대신 상위 층 몇 개만을 재학습하는 것이 일반적이고 이것은 더 적은 데이터로 더 빠르게 모델을 학습할 수 있도록 해준다.
#
#   - "fine_tuning_at = 120" 설정으로, 모델의 하위층인 120층 미만은 저수준 특징(선, 모서리 등)을 그대로 사용하면서 미세 조정되지 않는다. 반면, 120 이상의 상위층은 고수준 특징(개, 자동차 등)을 학습하여 새로운 데이터셋에 잘 적응하도록 돕는다.

# %%
fine_tuning_at = 140

# 0층부터 120층까지 layer을 학습 불가능하도록 가중치 고정
# 앞에 층은 보통 이미지의 저차원 수준의 특징을 나타내기 때문에 학습이 불 필요하다.
for layer in base_model.layers[:fine_tuning_at]:
  layer.trainable = False

# %%
# output은 모델의 마지막 출력 정보를 가지고있다.(conv층에 의해 생성, 16,16,2048형태로 데이터 출)
base_model.output

# %%
# output은 모델의 마지막 출력 정보를 가지고있다.(conv층에 의해 생성, 16,16,2048형태로 데이터 출)
head_model = base_model.output

# 출력된 행렬을 평균값을 이용하여 벡터로 변환해준다.
# 평탄화 함수를 사용할 수 있지만 GlobalAveragePooling2D()함수를 통해 평탄화 할수도 있다
head_model = GlobalAveragePooling2D()(head_model)

# 은닉층 1 -> 은닉층의 뉴런 수는 입력층(2048)과 출력층(클래스 수)의 평균값인 1025로 설정합니다.
head_model = Dense(units = 1025, activation = 'relu')(head_model)

# Dropout을 통해 20% 뉴런들을 비활성화하여 과적합 방지
head_model = Dropout(rate = 0.2)(head_model)

# 은닉층2
head_model = Dense(units = 1025, activation = 'relu')(head_model)

# Dropout을 통해 20% 뉴런들을 비활성화하여 과적합 방지
head_model = Dropout(rate = 0.2)(head_model)

# softmax 함수는 다중 클래스 분류 문제에서 사용, 각 클래스에 속할 확률을 계산 - > 모든 요소의 합은 1
# 크로스 엔트로피와 같은 일부 손실 함수 적용 가능
head_model = Dense(units=num_classes, activation='softmax')(head_model)  # num_classes는 클래스의 개수

# %%
# 두 신경망 연결하기 (Model (inputs = 입력에 사용될 신경망, outputs = 출력할 신경망))
network = Model(inputs = base_model.input, outputs= head_model)
# Out:
# 1028.5

# %%
# 주의점 : 요약의 평탄화의 입력shape을 보면 2048이다. 그냥 평탄화 함수를 썼으면 16*16*2048의 입력층이 나올것이다.
# 하지만 global_average_pooling2d를 사용함으로 입력층에 들어갈 데이터크기를 대폭 감소시킬수 있다.
network.summary()

# %% [markdown]
# ### 학습

# %% [markdown]
# #### 학습 진행

# %%
# GPU 확인
tf.config.list_physical_devices('GPU')

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

network.compile(optimizer=Adam(learning_rate=0.0008),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# loss가 제일 낮은 모델 가중치만 저장한다.
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, mode='min')
# 에포크가 진행됨에도 로스가 줄어들지 않다면 학습을 조기 종료한다.
early_stopping = EarlyStopping(monitor='val_loss', patience=5, mode='min')

history = network.fit(train_dataset,
            validation_data=valid_dataset,
            epochs=100,
            callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 94/94 [==============================] - ETA: 0s - loss: 3.0238 - accuracy: 0.1372
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 94/94 [==============================] - 247s 2s/step - loss: 3.0238 - accuracy: 0.1372 - val_loss: 2.2396 - val_accuracy: 0.0752
# Epoch 2/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.9173 - accuracy: 0.3076 - val_loss: 8.6828 - val_accuracy: 0.0391
# Epoch 3/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.9164 - accuracy: 0.3991 - val_loss: 13.7704 - val_accuracy: 0.0391
# Epoch 4/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.7875 - accuracy: 0.2412 - val_loss: 9.5443 - val_accuracy: 0.0391
# Epoch 5/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.6880 - accuracy: 0.3780 - val_loss: 7.6881 - val_accuracy: 0.0391
# Epoch 6/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.6061 - accuracy: 0.3896 - val_loss: 9.6400 - val_accuracy: 0.0391
# Epoch 7/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8470 - accuracy: 0.5107 - val_loss: 4.0379 - val_accuracy: 0.0512
# Epoch 8/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.7441 - accuracy: 0.4310 - val_loss: 21.7721 - val_accuracy: 0.0391
# Epoch 9/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.4619 - accuracy: 0.4947 - val_loss: 13.1748 - val_accuracy: 0.0391
# Epoch 10/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.4223 - accuracy: 0.4320 - val_loss: 5.0648 - val_accuracy: 0.0391
# Epoch 11/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.8644 - accuracy: 0.1404 - val_loss: 3.3729 - val_accuracy: 0.0391
# Epoch 12/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.6662 - accuracy: 0.4887 - val_loss: 15.7423 - val_accuracy: 0.0391
# Epoch 13/100
# 94/94 [==============================] - 235s 3s/step - loss: 1.5747 - accuracy: 0.3489 - val_loss: 2.2201 - val_accuracy: 0.0795
# Epoch 14/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.6787 - accuracy: 0.4050 - val_loss: 4.5252 - val_accuracy: 0.0795
# Epoch 15/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.7708 - accuracy: 0.3691 - val_loss: 4.4205 - val_accuracy: 0.0795
# Epoch 16/100
# 94/94 [==============================] - 232s 2s/step - loss: 2.0640 - accuracy: 0.2899 - val_loss: 5.2525 - val_accuracy: 0.0391
# Epoch 17/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.9434 - accuracy: 0.2753 - val_loss: 6.2898 - val_accuracy: 0.0391
# Epoch 18/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.8739 - accuracy: 0.2237 - val_loss: 6.4431 - val_accuracy: 0.0391
# Epoch 19/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.9021 - accuracy: 0.3821 - val_loss: 44.0818 - val_accuracy: 0.0391
# Epoch 20/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8662 - accuracy: 0.0815 - val_loss: 2.2440 - val_accuracy: 0.0795
# Epoch 21/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.9210 - accuracy: 0.0468 - val_loss: 2.2633 - val_accuracy: 0.0147
# Epoch 22/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.8985 - accuracy: 0.2096 - val_loss: 3.2918 - val_accuracy: 0.0391
# Epoch 23/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.6176 - accuracy: 0.3661 - val_loss: 6.6878 - val_accuracy: 0.0391
# Epoch 24/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.5926 - accuracy: 0.4445 - val_loss: 6.5026 - val_accuracy: 0.0795
# Epoch 25/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.5440 - accuracy: 0.4722 - val_loss: 14.7890 - val_accuracy: 0.0391
# Epoch 26/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.7312 - accuracy: 0.2981 - val_loss: 30.5791 - val_accuracy: 0.0391
# Epoch 27/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.5326 - accuracy: 0.4211 - val_loss: 15.3869 - val_accuracy: 0.0391
# Epoch 28/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.8422 - accuracy: 0.1909 - val_loss: 16.4051 - val_accuracy: 0.0391
# Epoch 29/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.7164 - accuracy: 0.2521 - val_loss: 14.1288 - val_accuracy: 0.0391
# Epoch 30/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.5046 - accuracy: 0.4391 - val_loss: 24.5209 - val_accuracy: 0.0391
# Epoch 31/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.2407 - accuracy: 0.6297 - val_loss: 36.8075 - val_accuracy: 0.0391
# Epoch 32/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.6448 - accuracy: 0.3835 - val_loss: 15.8976 - val_accuracy: 0.0391
# Epoch 33/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.6783 - accuracy: 0.3143 - val_loss: 27.5827 - val_accuracy: 0.0391
# Epoch 34/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8368 - accuracy: 0.2794 - val_loss: 11.7855 - val_accuracy: 0.0391
# Epoch 35/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8062 - accuracy: 0.2127 - val_loss: 2.7169 - val_accuracy: 0.0147
# Epoch 36/100
# 94/94 [==============================] - 236s 3s/step - loss: 1.7317 - accuracy: 0.2599 - val_loss: 2.1517 - val_accuracy: 0.3407
# Epoch 37/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8193 - accuracy: 0.2057 - val_loss: 7.1212 - val_accuracy: 0.0391
# Epoch 38/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.7048 - accuracy: 0.3028 - val_loss: 2.2751 - val_accuracy: 0.3407
# Epoch 39/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.5318 - accuracy: 0.3806 - val_loss: 3.4375 - val_accuracy: 0.3357
# Epoch 40/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.9028 - accuracy: 0.1666 - val_loss: 2.3825 - val_accuracy: 0.3407
# Epoch 41/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.9072 - accuracy: 0.0762 - val_loss: 2.3464 - val_accuracy: 0.0795
# Epoch 42/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.8980 - accuracy: 0.0604 - val_loss: 2.3298 - val_accuracy: 0.0795
# Epoch 43/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8951 - accuracy: 0.0525 - val_loss: 2.3284 - val_accuracy: 0.0795
# Epoch 44/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8924 - accuracy: 0.0425 - val_loss: 2.3363 - val_accuracy: 0.0795
# Epoch 45/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.8922 - accuracy: 0.0428 - val_loss: 2.3456 - val_accuracy: 0.0795
# Epoch 46/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.8910 - accuracy: 0.0393 - val_loss: 2.3515 - val_accuracy: 0.0795
# Epoch 47/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8906 - accuracy: 0.0373 - val_loss: 2.3588 - val_accuracy: 0.0795
# Epoch 48/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.8906 - accuracy: 0.0327 - val_loss: 2.3637 - val_accuracy: 0.0795
# Epoch 49/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.8901 - accuracy: 0.0305 - val_loss: 2.3669 - val_accuracy: 0.0795
# Epoch 50/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.8884 - accuracy: 0.0297 - val_loss: 2.3738 - val_accuracy: 0.0795
# Epoch 51/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8889 - accuracy: 0.0268 - val_loss: 2.3794 - val_accuracy: 0.0795
# Epoch 52/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8881 - accuracy: 0.0283 - val_loss: 2.3838 - val_accuracy: 0.0795
# Epoch 53/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8876 - accuracy: 0.0277 - val_loss: 2.3883 - val_accuracy: 0.0795
# Epoch 54/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.8871 - accuracy: 0.0280 - val_loss: 2.3925 - val_accuracy: 0.0795
# Epoch 55/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.8864 - accuracy: 0.0293 - val_loss: 2.3965 - val_accuracy: 0.0795
# Epoch 56/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.8877 - accuracy: 0.0263 - val_loss: 2.3990 - val_accuracy: 0.0795
# Epoch 57/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.8864 - accuracy: 0.0270 - val_loss: 2.4019 - val_accuracy: 0.0795
# Epoch 58/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8859 - accuracy: 0.0247 - val_loss: 2.4053 - val_accuracy: 0.0795
# Epoch 59/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8871 - accuracy: 0.0198 - val_loss: 2.4075 - val_accuracy: 0.0795
# Epoch 60/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8859 - accuracy: 0.0232 - val_loss: 2.4085 - val_accuracy: 0.0795
# Epoch 61/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.8850 - accuracy: 0.0210 - val_loss: 2.4148 - val_accuracy: 0.0795
# Epoch 62/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8847 - accuracy: 0.0227 - val_loss: 2.4144 - val_accuracy: 0.0795
# Epoch 63/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8850 - accuracy: 0.0227 - val_loss: 2.4152 - val_accuracy: 0.0795
# Epoch 64/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.8855 - accuracy: 0.0198 - val_loss: 2.4236 - val_accuracy: 0.0795
# Epoch 65/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8851 - accuracy: 0.0218 - val_loss: 2.4154 - val_accuracy: 0.0795
# Epoch 66/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8842 - accuracy: 0.0198 - val_loss: 2.4228 - val_accuracy: 0.0795
# Epoch 67/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.8849 - accuracy: 0.0220 - val_loss: 2.4151 - val_accuracy: 0.0795
# Epoch 68/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8840 - accuracy: 0.0198 - val_loss: 2.4335 - val_accuracy: 0.0795
# Epoch 69/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8842 - accuracy: 0.0213 - val_loss: 2.4288 - val_accuracy: 0.0795
# Epoch 70/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8849 - accuracy: 0.0263 - val_loss: 2.4246 - val_accuracy: 0.0795
# Epoch 71/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.7957 - accuracy: 0.2991 - val_loss: 63.7058 - val_accuracy: 0.0391
# Epoch 72/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.7562 - accuracy: 0.4345 - val_loss: 8.9664 - val_accuracy: 0.0795
# Epoch 73/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.6728 - accuracy: 0.4038 - val_loss: 5.9264 - val_accuracy: 0.0795
# Epoch 74/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.5340 - accuracy: 0.5970 - val_loss: 8.8997 - val_accuracy: 0.0391
# Epoch 75/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.6541 - accuracy: 0.4985 - val_loss: 30.9843 - val_accuracy: 0.0795
# Epoch 76/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.7628 - accuracy: 0.3279 - val_loss: 14.1587 - val_accuracy: 0.0391
# Epoch 77/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.5061 - accuracy: 0.4647 - val_loss: 17.5022 - val_accuracy: 0.0391
# Epoch 78/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.3219 - accuracy: 0.5378 - val_loss: 8.3085 - val_accuracy: 0.0391
# Epoch 79/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.5406 - accuracy: 0.4532 - val_loss: 23.1321 - val_accuracy: 0.0391
# Epoch 80/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.7107 - accuracy: 0.3590 - val_loss: 52.3849 - val_accuracy: 0.0391
# Epoch 81/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.7748 - accuracy: 0.3421 - val_loss: 27.0560 - val_accuracy: 0.0391
# Epoch 82/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.4268 - accuracy: 0.5053 - val_loss: 18.8825 - val_accuracy: 0.0391
# Epoch 83/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.6219 - accuracy: 0.3911 - val_loss: 61.7879 - val_accuracy: 0.0391
# Epoch 84/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8799 - accuracy: 0.3021 - val_loss: 21.3653 - val_accuracy: 0.0391
# Epoch 85/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.8471 - accuracy: 0.2266 - val_loss: 19.3604 - val_accuracy: 0.0391
# Epoch 86/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.9955 - accuracy: 0.1919 - val_loss: 2.4217 - val_accuracy: 0.3583
# Epoch 87/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8959 - accuracy: 0.1877 - val_loss: 7.6867 - val_accuracy: 0.0391
# Epoch 88/100
# 94/94 [==============================] - 233s 2s/step - loss: 2.0824 - accuracy: 0.0675 - val_loss: 2.6616 - val_accuracy: 0.1372
# Epoch 89/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.7982 - accuracy: 0.2596 - val_loss: 2.3368 - val_accuracy: 0.3583
# Epoch 90/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.9345 - accuracy: 0.0694 - val_loss: 2.3959 - val_accuracy: 0.3407
# Epoch 91/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.9175 - accuracy: 0.1155 - val_loss: 2.4000 - val_accuracy: 0.3407
# Epoch 92/100
# 94/94 [==============================] - 232s 2s/step - loss: 1.8972 - accuracy: 0.0847 - val_loss: 2.4096 - val_accuracy: 0.3407
# Epoch 93/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8949 - accuracy: 0.0779 - val_loss: 2.4248 - val_accuracy: 0.3407
# Epoch 94/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8935 - accuracy: 0.0690 - val_loss: 2.4382 - val_accuracy: 0.3407
# Epoch 95/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8927 - accuracy: 0.0595 - val_loss: 2.4501 - val_accuracy: 0.3407
# Epoch 96/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8917 - accuracy: 0.0585 - val_loss: 2.4600 - val_accuracy: 0.3407
# Epoch 97/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8914 - accuracy: 0.0475 - val_loss: 2.4695 - val_accuracy: 0.3407
# Epoch 98/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8914 - accuracy: 0.0448 - val_loss: 2.4769 - val_accuracy: 0.3407
# Epoch 99/100
# 94/94 [==============================] - 233s 2s/step - loss: 1.8909 - accuracy: 0.0422 - val_loss: 2.4840 - val_accuracy: 0.3407
# Epoch 100/100
# 94/94 [==============================] - 234s 2s/step - loss: 1.8900 - accuracy: 0.0417 - val_loss: 2.4905 - val_accuracy: 0.0795

# %% [markdown]
# #### 학습된 모델 저장 및 불러오기
# - save로 모델저장
#   - 학습 결과가 폴더로 생성된다.
#     - saved_model.pd 는 신경망 모델의 구조를 나타낸다
#     - variables는 가중치를 나타낸다
#   - 모델을 불러올때도 폴더 전체를 불러와야한다.
# - 가중치 및 구조를 따로 저장
#   - 모델의 구조를 json으로 저장
#     - model.to_json()함수 사용
#   - 가중치는 h5(HDF5)파일로 저장
#     - model.save_weights("파일경로")함수 사용
# - keras 모델을 사용할때 가중치와 구조를 한파일로 저장
#   - model.save("model.h5") 함수 사용

# %%
# 모델 저장 ( 가중치 및 구조가 같이 저장됨 )
network.save("/content/saved_model")

# %%
# 모델 불러오기
loaded_ = tf.keras.models.load_model("/content/best_model.h5")

# %%
loaded_.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 518, 518, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 256, 256, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 256, 256, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 256, 256, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 258, 258, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 128, 128, 64)         0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 128, 128, 64)         4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 128, 128, 64)         36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 128, 128, 256)        16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 128, 128, 256)        16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 128, 128, 256)        0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 128, 128, 256)        0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 128, 128, 64)         16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 128, 128, 64)         36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 128, 128, 256)        16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 128, 128, 256)        0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 128, 128, 256)        0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 128, 128, 64)         16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 128, 128, 64)         36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 128, 128, 256)        16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 128, 128, 256)        0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 128, 128, 256)        0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 64, 64, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 64, 64, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 64, 64, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 64, 64, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 64, 64, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 64, 64, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 64, 64, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 64, 64, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 64, 64, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 64, 64, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 64, 64, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 64, 64, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 64, 64, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 32, 32, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 32, 32, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 16, 16, 512)          524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 16, 16, 512)          2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 16, 16, 2048)         2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 16, 16, 2048)         1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 16, 16, 2048)         0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 16, 16, 2048)         0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 16, 16, 512)          1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 16, 16, 512)          2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 16, 16, 2048)         1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 16, 16, 2048)         0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 16, 16, 2048)         0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 16, 16, 512)          1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 16, 16, 512)          2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 16, 16, 2048)         1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 16, 16, 2048)         0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 16, 16, 2048)         0         ['conv5_block3_add[0][0]']
#  on)
#
#  global_average_pooling2d (  (None, 2048)                 0         ['conv5_block3_out[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1025)                 2100225   ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 1025)                 0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1025)                 1051650   ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 1025)                 0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 9)                    9234      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 26748821 (102.04 MB)
# Trainable params: 20376597 (77.73 MB)
# Non-trainable params: 6372224 (24.31 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# #### 학습 결과 분석 (시각화)
# - 에포크 마다 정확도 그래프 보기
# - 에포크 마다 손실 그래프 보기

# %%
import matplotlib.pyplot as plt
# 학습 및 검증 손실 값을 플로팅
plt.figure(figsize=(12, 4))

# 학습 손실 그래프
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 학습 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
